# %%
import keras
from context import * # imports the MDN layer 
import numpy as np
import random
import matplotlib.pyplot as plt
import tensorflow as tf
import keras.backend as K
# %matplotlib inline
import h5py
from keras.models import model_from_json
from keras.optimizers import Adam
from predictions import define_models, mdn_predict_sequence, predict_z
from midi_handling import switch_range, noteArrayToStream
from keras.utils import multi_gpu_model
from my_classes import MDNDataGenerator
from data_prep import one_hot_decode
from music21 import converter, instrument, note, chord, stream, midi, environment
# Only for GPU use:
#os.environ["CUDA_VISIBLE_DEVICES"]="1"


config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
K.set_session(sess)

mdn_dataset_path = "h5_files/mdn_dataset_pre.h5"
vae_weights_path = "weights/512_64/weights-improvement-2455-1.00.hdf5"

############################ MDN initalisation ###################################
SEQ_LEN = 16
BATCH_SIZE = 64
HIDDEN_UNITS = 512
EPOCHS = 400
SEED = 2345  # set random seed for reproducibility


OUTPUT_DIMENSION = 64
NUMBER_MIXTURES = 10

random.seed(SEED)
np.random.seed(SEED)
############################ VAE initalisation ###################################
n_features = 131
timesteps = 16
learning_rate = 0.0001
n_encoder_units = 512
n_decoder_units = n_encoder_units
latent_dim = 64
dropout=0.3
beta=1
############################ MUSESCORE intialisation ###############################
environment.set("musescoreDirectPNGPath", "/usr/bin/musescore")

# %% [markdown]
# ### Setup an MDN RNN

# %%
inputs = keras.layers.Input(shape=(SEQ_LEN,OUTPUT_DIMENSION), name='inputs')
lstm1_out = keras.layers.LSTM(HIDDEN_UNITS, name='lstm1', return_sequences=True)(inputs)
lstm2_out = keras.layers.LSTM(HIDDEN_UNITS, name='lstm2', return_sequences=True)(lstm1_out)
mdn_out = keras.layers.TimeDistributed(mdn.MDN(OUTPUT_DIMENSION, NUMBER_MIXTURES, name='mdn_outputs'), name='td_mdn')(lstm2_out)

model = keras.models.Model(inputs=inputs, outputs=mdn_out)
optimizer = Adam(clipnorm=1., lr=0.0001)
#model = multi_gpu_model(model, gpus=2)
model.compile(loss=mdn.get_mixture_loss_func(OUTPUT_DIMENSION,NUMBER_MIXTURES), optimizer=optimizer)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          (None, 16, 64)            0
# _________________________________________________________________
# lstm1 (LSTM)                 (None, 16, 512)           1181696
# _________________________________________________________________
# lstm2 (LSTM)                 (None, 16, 512)           2099200
# _________________________________________________________________
# td_mdn (TimeDistributed)     (None, 16, 1290)          661770
# =================================================================
# Total params: 3,942,666
# Trainable params: 3,942,666
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Get generator info

# %%
num_training_samples = 10000
num_validation_samples = 1000
steps_per_epoch = int(num_training_samples / BATCH_SIZE)
validation_steps = int(num_validation_samples / BATCH_SIZE)

params = {'dim': (SEQ_LEN, OUTPUT_DIMENSION),
          'batch_size': BATCH_SIZE,
          'dataset_path': mdn_dataset_path, ### IMPORTANT
          'shuffle': True}

ID_list_dict = {}

# Datasets
ID_list = np.load("ID_lists/mdn_ID_list_pre.npy")

ID_list_dict["train"] = ID_list.item().get("train")
ID_list_dict["validation"] = ID_list.item().get("validation")

# Generators
training_generator = MDNDataGenerator(ID_list_dict['train'], **params)
validation_generator = MDNDataGenerator(ID_list_dict['validation'], **params)

# %%
# Train model on dataset
filepath="weights/MDN_pre-weights-improvement-{epoch:02d}-{val_loss:.2f}.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
tensorboard = keras.callbacks.TensorBoard(log_dir="tb_trained_models/mdnpre", batch_size=BATCH_SIZE)

history = model.fit_generator(generator=training_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    use_multiprocessing=False,
                    epochs=EPOCHS,verbose=2,callbacks=[keras.callbacks.TerminateOnNaN(),
                                                       checkpoint,
                                                       tensorboard])
# Out:
# Epoch 1/400
#  - 8s - loss: 220.5272 - val_loss: 202.7098
#
# Epoch 00001: val_loss improved from inf to 202.70976, saving model to weights/MDN_pre-weights-improvement-01-202.71.hdf5
# Epoch 2/400
#  - 8s - loss: 218.4642 - val_loss: 197.6292
#
# Epoch 00002: val_loss improved from 202.70976 to 197.62919, saving model to weights/MDN_pre-weights-improvement-02-197.63.hdf5
# Epoch 3/400
#  - 8s - loss: 217.0276 - val_loss: 191.4881
#
# Epoch 00003: val_loss improved from 197.62919 to 191.48811, saving model to weights/MDN_pre-weights-improvement-03-191.49.hdf5
# Epoch 4/400
#  - 8s - loss: 215.5447 - val_loss: 187.5852
#
# Epoch 00004: val_loss improved from 191.48811 to 187.58519, saving model to weights/MDN_pre-weights-improvement-04-187.59.hdf5
# Epoch 5/400
#  - 8s - loss: 215.0865 - val_loss: 184.4206
#
# Epoch 00005: val_loss improved from 187.58519 to 184.42064, saving model to weights/MDN_pre-weights-improvement-05-184.42.hdf5
# Epoch 6/400
#  - 8s - loss: 213.6780 - val_loss: 181.2980
#
# Epoch 00006: val_loss improved from 184.42064 to 181.29797, saving model to weights/MDN_pre-weights-improvement-06-181.30.hdf5
# Epoch 7/400
#  - 8s - loss: 213.8725 - val_loss: 182.2244
#
# Epoch 00007: val_loss did not improve from 181.29797
# Epoch 8/400
#  - 8s - loss: 212.7454 - val_loss: 181.1276
#
# Epoch 00008: val_loss improved from 181.29797 to 181.12762, saving model to weights/MDN_pre-weights-improvement-08-181.13.hdf5
# Epoch 9/400
#  - 8s - loss: 213.1703 - val_loss: 178.8758
#
# Epoch 00009: val_loss improved from 181.12762 to 178.87579, saving model to weights/MDN_pre-weights-improvement-09-178.88.hdf5
# Epoch 10/400
#  - 8s - loss: 211.9557 - val_loss: 177.1105
#
# Epoch 00010: val_loss improved from 178.87579 to 177.11055, saving model to weights/MDN_pre-weights-improvement-10-177.11.hdf5
# Epoch 11/400
#  - 8s - loss: 212.4525 - val_loss: 178.1308
#
# Epoch 00011: val_loss did not improve from 177.11055
# Epoch 12/400
#  - 8s - loss: 212.4927 - val_loss: 181.3285
#
# Epoch 00012: val_loss did not improve from 177.11055
# Epoch 13/400
#  - 8s - loss: 212.0750 - val_loss: 179.1016
#
# Epoch 00013: val_loss did not improve from 177.11055
# Epoch 14/400
#  - 8s - loss: 211.9800 - val_loss: 176.5305
#
# Epoch 00014: val_loss improved from 177.11055 to 176.53052, saving model to weights/MDN_pre-weights-improvement-14-176.53.hdf5
# Epoch 15/400
#  - 8s - loss: 211.9530 - val_loss: 179.3406
#
# Epoch 00015: val_loss did not improve from 176.53052
# Epoch 16/400
#  - 8s - loss: 211.4266 - val_loss: 177.2395
#
# Epoch 00016: val_loss did not improve from 176.53052
# Epoch 17/400
#  - 8s - loss: 212.1253 - val_loss: 179.5316
#
# Epoch 00017: val_loss did not improve from 176.53052
# Epoch 18/400
#  - 8s - loss: 211.1673 - val_loss: 180.7757
#
# Epoch 00018: val_loss did not improve from 176.53052
# Epoch 19/400
#  - 9s - loss: 211.4346 - val_loss: 178.1199
#
# Epoch 00019: val_loss did not improve from 176.53052
# Epoch 20/400
#  - 8s - loss: 211.7877 - val_loss: 179.8064
#
# Epoch 00020: val_loss did not improve from 176.53052
# Epoch 21/400
#  - 8s - loss: 211.0295 - val_loss: 179.3996
#
# Epoch 00021: val_loss did not improve from 176.53052
# Epoch 22/400
#  - 8s - loss: 210.4690 - val_loss: 177.8260
#
# Epoch 00022: val_loss did not improve from 176.53052
# Epoch 23/400
#  - 8s - loss: 211.1489 - val_loss: 177.5080
#
# Epoch 00023: val_loss did not improve from 176.53052
# Epoch 24/400
#  - 8s - loss: 210.5876 - val_loss: 178.8522
#
# Epoch 00024: val_loss did not improve from 176.53052
# Epoch 25/400
#  - 8s - loss: 211.0063 - val_loss: 177.2652
#
# Epoch 00025: val_loss did not improve from 176.53052
# Epoch 26/400
#  - 8s - loss: 210.7101 - val_loss: 179.7083
#
# Epoch 00026: val_loss did not improve from 176.53052
# Epoch 27/400
#  - 8s - loss: 209.5304 - val_loss: 178.8089
#
# Epoch 00027: val_loss did not improve from 176.53052
# Epoch 28/400
#  - 8s - loss: 210.0581 - val_loss: 176.9363
#
# Epoch 00028: val_loss did not improve from 176.53052
# Epoch 29/400
#  - 8s - loss: 210.1969 - val_loss: 176.2929
#
# Epoch 00029: val_loss improved from 176.53052 to 176.29291, saving model to weights/MDN_pre-weights-improvement-29-176.29.hdf5
# Epoch 30/400
#  - 8s - loss: 209.1105 - val_loss: 174.1944
#
# Epoch 00030: val_loss improved from 176.29291 to 174.19443, saving model to weights/MDN_pre-weights-improvement-30-174.19.hdf5
# Epoch 31/400
#  - 8s - loss: 210.5328 - val_loss: 176.9506
#
# Epoch 00031: val_loss did not improve from 174.19443
# Epoch 32/400
#  - 8s - loss: 208.8827 - val_loss: 177.8709
#
# Epoch 00032: val_loss did not improve from 174.19443
# Epoch 33/400
#  - 8s - loss: 209.9051 - val_loss: 177.8612
#
# Epoch 00033: val_loss did not improve from 174.19443
# Epoch 34/400
#  - 8s - loss: 206.8754 - val_loss: 165.5357
#
# Epoch 00034: val_loss improved from 174.19443 to 165.53567, saving model to weights/MDN_pre-weights-improvement-34-165.54.hdf5
# Epoch 35/400
#  - 8s - loss: 202.7862 - val_loss: 164.9144
#
# Epoch 00035: val_loss improved from 165.53567 to 164.91435, saving model to weights/MDN_pre-weights-improvement-35-164.91.hdf5
# Epoch 36/400
#  - 8s - loss: 201.5673 - val_loss: 166.6569
#
# Epoch 00036: val_loss did not improve from 164.91435
# Epoch 37/400
#  - 8s - loss: 201.4981 - val_loss: 164.8047
#
# Epoch 00037: val_loss improved from 164.91435 to 164.80473, saving model to weights/MDN_pre-weights-improvement-37-164.80.hdf5
# Epoch 38/400
#  - 8s - loss: 201.7989 - val_loss: 158.0359
#
# Epoch 00038: val_loss improved from 164.80473 to 158.03587, saving model to weights/MDN_pre-weights-improvement-38-158.04.hdf5
# Epoch 39/400
#  - 8s - loss: 200.7443 - val_loss: 165.2784
#
# Epoch 00039: val_loss did not improve from 158.03587
# Epoch 40/400
#  - 8s - loss: 200.2625 - val_loss: 165.3115
#
# Epoch 00040: val_loss did not improve from 158.03587
# Epoch 41/400
#  - 8s - loss: 199.9708 - val_loss: 162.1372
#
# Epoch 00041: val_loss did not improve from 158.03587
# Epoch 42/400
#  - 8s - loss: 199.8797 - val_loss: 161.3772
#
# Epoch 00042: val_loss did not improve from 158.03587
# Epoch 43/400
#  - 8s - loss: 199.2482 - val_loss: 164.8792
#
# Epoch 00043: val_loss did not improve from 158.03587
# Epoch 44/400
#  - 8s - loss: 199.2093 - val_loss: 159.2639
#
# Epoch 00044: val_loss did not improve from 158.03587
# Epoch 45/400
#  - 8s - loss: 199.5699 - val_loss: 162.0243
#
# Epoch 00045: val_loss did not improve from 158.03587
# Epoch 46/400
#  - 8s - loss: 197.4501 - val_loss: 159.1950
#
# Epoch 00046: val_loss did not improve from 158.03587
# Epoch 47/400
#  - 8s - loss: 198.0807 - val_loss: 158.1229
#
# Epoch 00047: val_loss did not improve from 158.03587
# Epoch 48/400
#  - 8s - loss: 197.7586 - val_loss: 162.2798
#
# Epoch 00048: val_loss did not improve from 158.03587
# Epoch 49/400
#  - 8s - loss: 197.1019 - val_loss: 163.1859
#
# Epoch 00049: val_loss did not improve from 158.03587
# Epoch 50/400
#  - 7s - loss: 197.8772 - val_loss: 160.4298
#
# Epoch 00050: val_loss did not improve from 158.03587
# Epoch 51/400
#  - 8s - loss: 196.8062 - val_loss: 158.4440
#
# Epoch 00051: val_loss did not improve from 158.03587
# Epoch 52/400
#  - 8s - loss: 196.9114 - val_loss: 163.5060
#
# Epoch 00052: val_loss did not improve from 158.03587
# Epoch 53/400
#  - 8s - loss: 197.3348 - val_loss: 156.2953
#
# Epoch 00053: val_loss improved from 158.03587 to 156.29531, saving model to weights/MDN_pre-weights-improvement-53-156.30.hdf5
# Epoch 54/400
#  - 8s - loss: 196.9056 - val_loss: 164.5942
#
# Epoch 00054: val_loss did not improve from 156.29531
# Epoch 55/400
#  - 8s - loss: 196.4365 - val_loss: 160.4518
#
# Epoch 00055: val_loss did not improve from 156.29531
# Epoch 56/400
#  - 8s - loss: 196.6588 - val_loss: 160.5446
#
# Epoch 00056: val_loss did not improve from 156.29531
# Epoch 57/400
#  - 8s - loss: 196.0828 - val_loss: 159.5455
#
# Epoch 00057: val_loss did not improve from 156.29531
# Epoch 58/400
#  - 8s - loss: 196.0109 - val_loss: 161.9075
#
# Epoch 00058: val_loss did not improve from 156.29531
# Epoch 59/400
#  - 8s - loss: 195.6676 - val_loss: 161.1234
#
# Epoch 00059: val_loss did not improve from 156.29531
# Epoch 60/400
#  - 9s - loss: 195.8111 - val_loss: 159.0655
#
# Epoch 00060: val_loss did not improve from 156.29531
# Epoch 61/400
#  - 8s - loss: 195.7628 - val_loss: 161.9685
#
# Epoch 00061: val_loss did not improve from 156.29531
# Epoch 62/400
#  - 7s - loss: 195.7780 - val_loss: 160.7927
#
# Epoch 00062: val_loss did not improve from 156.29531
# Epoch 63/400
#  - 8s - loss: 195.8751 - val_loss: 160.4117
#
# Epoch 00063: val_loss did not improve from 156.29531
# Epoch 64/400
#  - 8s - loss: 195.2474 - val_loss: 161.4961
#
# Epoch 00064: val_loss did not improve from 156.29531
# Epoch 65/400
#  - 8s - loss: 195.3830 - val_loss: 159.0438
#
# Epoch 00065: val_loss did not improve from 156.29531
# Epoch 66/400
#  - 8s - loss: 195.0084 - val_loss: 162.2399
#
# Epoch 00066: val_loss did not improve from 156.29531
# Epoch 67/400
#  - 8s - loss: 195.1723 - val_loss: 162.3675
#
# Epoch 00067: val_loss did not improve from 156.29531
# Epoch 68/400
#  - 8s - loss: 194.7689 - val_loss: 159.4385
#
# Epoch 00068: val_loss did not improve from 156.29531
# Epoch 69/400
#  - 8s - loss: 195.0159 - val_loss: 162.9695
#
# Epoch 00069: val_loss did not improve from 156.29531
# Epoch 70/400
#  - 8s - loss: 194.9081 - val_loss: 157.4935
#
# Epoch 00070: val_loss did not improve from 156.29531
# Epoch 71/400
#  - 8s - loss: 194.9674 - val_loss: 161.1680
#
# Epoch 00071: val_loss did not improve from 156.29531
# Epoch 72/400
#  - 8s - loss: 194.3282 - val_loss: 157.2329
#
# Epoch 00072: val_loss did not improve from 156.29531
# Epoch 73/400
#  - 8s - loss: 194.5114 - val_loss: 162.1592
#
# Epoch 00073: val_loss did not improve from 156.29531
# Epoch 74/400
#  - 8s - loss: 194.3751 - val_loss: 156.2284
#
# Epoch 00074: val_loss improved from 156.29531 to 156.22841, saving model to weights/MDN_pre-weights-improvement-74-156.23.hdf5
# Epoch 75/400
#  - 8s - loss: 194.6271 - val_loss: 158.7516
#
# Epoch 00075: val_loss did not improve from 156.22841
# Epoch 76/400
#  - 8s - loss: 194.4101 - val_loss: 162.0790
#
# Epoch 00076: val_loss did not improve from 156.22841
# Epoch 77/400
#  - 8s - loss: 193.9874 - val_loss: 158.6439
#
# Epoch 00077: val_loss did not improve from 156.22841
# Epoch 78/400
#  - 8s - loss: 194.5135 - val_loss: 159.5600
#
# Epoch 00078: val_loss did not improve from 156.22841
# Epoch 79/400
#  - 8s - loss: 193.4863 - val_loss: 159.0995
#
# Epoch 00079: val_loss did not improve from 156.22841
# Epoch 80/400
#  - 8s - loss: 194.4675 - val_loss: 160.9723
#
# Epoch 00080: val_loss did not improve from 156.22841
# Epoch 81/400
#  - 8s - loss: 193.5635 - val_loss: 158.0496
#
# Epoch 00081: val_loss did not improve from 156.22841
# Epoch 82/400
#  - 8s - loss: 193.9769 - val_loss: 159.2106
#
# Epoch 00082: val_loss did not improve from 156.22841
# Epoch 83/400
#  - 8s - loss: 193.2125 - val_loss: 161.7642
#
# Epoch 00083: val_loss did not improve from 156.22841
# Epoch 84/400
#  - 8s - loss: 194.1049 - val_loss: 159.2908
#
# Epoch 00084: val_loss did not improve from 156.22841
# Epoch 85/400
#  - 8s - loss: 193.7631 - val_loss: 163.4937
#
# Epoch 00085: val_loss did not improve from 156.22841
# Epoch 86/400
#  - 8s - loss: 193.4995 - val_loss: 155.2796
#
# Epoch 00086: val_loss improved from 156.22841 to 155.27964, saving model to weights/MDN_pre-weights-improvement-86-155.28.hdf5
# Epoch 87/400
#  - 8s - loss: 193.6278 - val_loss: 159.1282
#
# Epoch 00087: val_loss did not improve from 155.27964
# Epoch 88/400
#  - 8s - loss: 193.4328 - val_loss: 163.1431
#
# Epoch 00088: val_loss did not improve from 155.27964
# Epoch 89/400
#  - 8s - loss: 193.6330 - val_loss: 158.3126
#
# Epoch 00089: val_loss did not improve from 155.27964
# Epoch 90/400
#  - 8s - loss: 193.3710 - val_loss: 159.6513
#
# Epoch 00090: val_loss did not improve from 155.27964
# Epoch 91/400
#  - 8s - loss: 192.6714 - val_loss: 160.4165
#
# Epoch 00091: val_loss did not improve from 155.27964
# Epoch 92/400
#  - 8s - loss: 193.4209 - val_loss: 159.4914
#
# Epoch 00092: val_loss did not improve from 155.27964
# Epoch 93/400
#  - 8s - loss: 193.1755 - val_loss: 161.0312
#
# Epoch 00093: val_loss did not improve from 155.27964
# Epoch 94/400
#  - 8s - loss: 193.1403 - val_loss: 159.3117
#
# Epoch 00094: val_loss did not improve from 155.27964
# Epoch 95/400
#  - 8s - loss: 192.7555 - val_loss: 159.1449
#
# Epoch 00095: val_loss did not improve from 155.27964
# Epoch 96/400
#  - 8s - loss: 192.6280 - val_loss: 156.5399
#
# Epoch 00096: val_loss did not improve from 155.27964
# Epoch 97/400
#  - 8s - loss: 193.8501 - val_loss: 162.3308
#
# Epoch 00097: val_loss did not improve from 155.27964
# Epoch 98/400
#  - 8s - loss: 192.8159 - val_loss: 159.6911
#
# Epoch 00098: val_loss did not improve from 155.27964
# Epoch 99/400
#  - 8s - loss: 192.6090 - val_loss: 160.2014
#
# Epoch 00099: val_loss did not improve from 155.27964
# Epoch 100/400
#  - 8s - loss: 193.1912 - val_loss: 160.2122
#
# Epoch 00100: val_loss did not improve from 155.27964
# Epoch 101/400
#  - 8s - loss: 192.7201 - val_loss: 158.1521
#
# Epoch 00101: val_loss did not improve from 155.27964
# Epoch 102/400
#  - 8s - loss: 192.3200 - val_loss: 159.7866
#
# Epoch 00102: val_loss did not improve from 155.27964
# Epoch 103/400
#  - 8s - loss: 192.7372 - val_loss: 159.0443
#
# Epoch 00103: val_loss did not improve from 155.27964
# Epoch 104/400
#  - 8s - loss: 192.4271 - val_loss: 159.3366
#
# Epoch 00104: val_loss did not improve from 155.27964
# Epoch 105/400
#  - 8s - loss: 192.9502 - val_loss: 160.4400
#
# Epoch 00105: val_loss did not improve from 155.27964
# Epoch 106/400
#  - 8s - loss: 192.0499 - val_loss: 161.8926
#
# Epoch 00106: val_loss did not improve from 155.27964
# Epoch 107/400
#  - 8s - loss: 192.9458 - val_loss: 155.3981
#
# Epoch 00107: val_loss did not improve from 155.27964
# Epoch 108/400
#  - 8s - loss: 192.4224 - val_loss: 162.5317
#
# Epoch 00108: val_loss did not improve from 155.27964
# Epoch 109/400
#  - 8s - loss: 191.9518 - val_loss: 161.1871
#
# Epoch 00109: val_loss did not improve from 155.27964
# Epoch 110/400
#  - 8s - loss: 192.0680 - val_loss: 162.7836
#
# Epoch 00110: val_loss did not improve from 155.27964
# Epoch 111/400
#  - 8s - loss: 192.1746 - val_loss: 157.4389
#
# Epoch 00111: val_loss did not improve from 155.27964
# Epoch 112/400
#  - 8s - loss: 192.6342 - val_loss: 158.3856
#
# Epoch 00112: val_loss did not improve from 155.27964
# Epoch 113/400
#  - 8s - loss: 192.2449 - val_loss: 160.7071
#
# Epoch 00113: val_loss did not improve from 155.27964
# Epoch 114/400
#  - 8s - loss: 192.3816 - val_loss: 163.4036
#
# Epoch 00114: val_loss did not improve from 155.27964
# Epoch 115/400
#  - 8s - loss: 191.8522 - val_loss: 161.2833
#
# Epoch 00115: val_loss did not improve from 155.27964
# Epoch 116/400
#  - 8s - loss: 191.7357 - val_loss: 161.8638
#
# Epoch 00116: val_loss did not improve from 155.27964
# Epoch 117/400
#  - 8s - loss: 192.3790 - val_loss: 159.6964
#
# Epoch 00117: val_loss did not improve from 155.27964
# Epoch 118/400
#  - 8s - loss: 191.5810 - val_loss: 154.7514
#
# Epoch 00118: val_loss improved from 155.27964 to 154.75139, saving model to weights/MDN_pre-weights-improvement-118-154.75.hdf5
# Epoch 119/400
#  - 8s - loss: 191.9169 - val_loss: 161.0381
#
# Epoch 00119: val_loss did not improve from 154.75139
# Epoch 120/400
#  - 8s - loss: 191.4372 - val_loss: 162.8717
#
# Epoch 00120: val_loss did not improve from 154.75139
# Epoch 121/400
#  - 8s - loss: 192.6480 - val_loss: 158.1305
#
# Epoch 00121: val_loss did not improve from 154.75139
# Epoch 122/400
#  - 8s - loss: 191.4679 - val_loss: 161.4965
#
# Epoch 00122: val_loss did not improve from 154.75139
# Epoch 123/400
#  - 8s - loss: 191.7639 - val_loss: 157.1339
#
# Epoch 00123: val_loss did not improve from 154.75139
# Epoch 124/400
#  - 8s - loss: 191.1149 - val_loss: 160.0418
#
# Epoch 00124: val_loss did not improve from 154.75139
# Epoch 125/400
#  - 8s - loss: 191.9236 - val_loss: 155.8324
#
# Epoch 00125: val_loss did not improve from 154.75139
# Epoch 126/400
#  - 8s - loss: 192.0275 - val_loss: 159.8603
#
# Epoch 00126: val_loss did not improve from 154.75139
# Epoch 127/400
#  - 8s - loss: 191.7104 - val_loss: 159.8905
#
# Epoch 00127: val_loss did not improve from 154.75139
# Epoch 128/400
#  - 8s - loss: 191.3289 - val_loss: 156.4748
#
# Epoch 00128: val_loss did not improve from 154.75139
# Epoch 129/400
#  - 8s - loss: 191.8259 - val_loss: 158.1243
#
# Epoch 00129: val_loss did not improve from 154.75139
# Epoch 130/400
#  - 8s - loss: 190.9613 - val_loss: 160.5730
#
# Epoch 00130: val_loss did not improve from 154.75139
# Epoch 131/400
#  - 8s - loss: 191.4668 - val_loss: 160.2515
#
# Epoch 00131: val_loss did not improve from 154.75139
# Epoch 132/400
#  - 8s - loss: 191.6601 - val_loss: 160.3548
#
# Epoch 00132: val_loss did not improve from 154.75139
# Epoch 133/400
#  - 8s - loss: 191.2784 - val_loss: 161.0056
#
# Epoch 00133: val_loss did not improve from 154.75139
# Epoch 134/400
#  - 8s - loss: 191.2536 - val_loss: 161.2790
#
# Epoch 00134: val_loss did not improve from 154.75139
# Epoch 135/400
#  - 8s - loss: 191.6970 - val_loss: 161.0453
#
# Epoch 00135: val_loss did not improve from 154.75139
# Epoch 136/400
#  - 8s - loss: 191.0241 - val_loss: 158.5337
#
# Epoch 00136: val_loss did not improve from 154.75139
# Epoch 137/400
#  - 8s - loss: 191.4994 - val_loss: 159.4754
#
# Epoch 00137: val_loss did not improve from 154.75139
# Epoch 138/400
#  - 8s - loss: 190.2313 - val_loss: 159.1614
#
# Epoch 00138: val_loss did not improve from 154.75139
# Epoch 139/400
#  - 8s - loss: 191.6687 - val_loss: 159.3177
#
# Epoch 00139: val_loss did not improve from 154.75139
# Epoch 140/400
#  - 8s - loss: 191.5078 - val_loss: 158.9163
#
# Epoch 00140: val_loss did not improve from 154.75139
# Epoch 141/400
#  - 8s - loss: 190.3764 - val_loss: 159.9976
#
# Epoch 00141: val_loss did not improve from 154.75139
# Epoch 142/400
#  - 8s - loss: 191.3900 - val_loss: 161.4008
#
# Epoch 00142: val_loss did not improve from 154.75139
# Epoch 143/400
#  - 8s - loss: 191.4091 - val_loss: 158.3738
#
# Epoch 00143: val_loss did not improve from 154.75139
# Epoch 144/400
#  - 8s - loss: 191.1574 - val_loss: 159.4644
#
# Epoch 00144: val_loss did not improve from 154.75139
# Epoch 145/400
#  - 8s - loss: 190.7504 - val_loss: 157.1598
#
# Epoch 00145: val_loss did not improve from 154.75139
# Epoch 146/400
#  - 8s - loss: 190.2528 - val_loss: 161.6330
#
# Epoch 00146: val_loss did not improve from 154.75139
# Epoch 147/400
#  - 8s - loss: 191.3181 - val_loss: 159.5648
#
# Epoch 00147: val_loss did not improve from 154.75139
# Epoch 148/400
#  - 8s - loss: 191.1207 - val_loss: 157.8475
#
# Epoch 00148: val_loss did not improve from 154.75139
# Epoch 149/400
#  - 8s - loss: 191.1272 - val_loss: 160.4975
#
# Epoch 00149: val_loss did not improve from 154.75139
# Epoch 150/400
#  - 8s - loss: 190.6400 - val_loss: 160.1880
#
# Epoch 00150: val_loss did not improve from 154.75139
# Epoch 151/400
#  - 8s - loss: 191.2970 - val_loss: 160.3677
#
# Epoch 00151: val_loss did not improve from 154.75139
# Epoch 152/400
#  - 8s - loss: 190.3169 - val_loss: 163.3214
#
# Epoch 00152: val_loss did not improve from 154.75139
# Epoch 153/400
#  - 8s - loss: 190.5995 - val_loss: 161.8894
#
# Epoch 00153: val_loss did not improve from 154.75139
# Epoch 154/400
#  - 8s - loss: 190.9487 - val_loss: 161.0359
#
# Epoch 00154: val_loss did not improve from 154.75139
# Epoch 155/400
#  - 8s - loss: 190.6579 - val_loss: 158.1656
#
# Epoch 00155: val_loss did not improve from 154.75139
# Epoch 156/400
#  - 8s - loss: 190.6908 - val_loss: 157.2578
#
# Epoch 00156: val_loss did not improve from 154.75139
# Epoch 157/400
#  - 8s - loss: 190.3381 - val_loss: 162.7193
#
# Epoch 00157: val_loss did not improve from 154.75139
# Epoch 158/400
#  - 8s - loss: 190.6971 - val_loss: 157.5565
#
# Epoch 00158: val_loss did not improve from 154.75139
# Epoch 159/400
#  - 8s - loss: 190.0692 - val_loss: 158.2671
#
# Epoch 00159: val_loss did not improve from 154.75139
# Epoch 160/400
#  - 8s - loss: 190.7625 - val_loss: 159.4487
#
# Epoch 00160: val_loss did not improve from 154.75139
# Epoch 161/400
#  - 8s - loss: 190.4635 - val_loss: 160.0405
#
# Epoch 00161: val_loss did not improve from 154.75139
# Epoch 162/400
#  - 8s - loss: 190.7318 - val_loss: 162.1086
#
# Epoch 00162: val_loss did not improve from 154.75139
# Epoch 163/400
#  - 8s - loss: 190.7291 - val_loss: 158.1190
#
# Epoch 00163: val_loss did not improve from 154.75139
# Epoch 164/400
#  - 8s - loss: 190.3464 - val_loss: 162.4924
#
# Epoch 00164: val_loss did not improve from 154.75139
# Epoch 165/400
#  - 8s - loss: 190.9090 - val_loss: 158.0140
#
# Epoch 00165: val_loss did not improve from 154.75139
# Epoch 166/400
#  - 8s - loss: 190.2073 - val_loss: 161.4986
#
# Epoch 00166: val_loss did not improve from 154.75139
# Epoch 167/400
#  - 8s - loss: 190.1433 - val_loss: 157.0629
#
# Epoch 00167: val_loss did not improve from 154.75139
# Epoch 168/400
#  - 8s - loss: 190.0691 - val_loss: 163.2522
#
# Epoch 00168: val_loss did not improve from 154.75139
# Epoch 169/400
#  - 8s - loss: 190.6599 - val_loss: 157.4795
#
# Epoch 00169: val_loss did not improve from 154.75139
# Epoch 170/400
#  - 8s - loss: 190.3086 - val_loss: 158.1734
#
# Epoch 00170: val_loss did not improve from 154.75139
# Epoch 171/400
#  - 8s - loss: 189.7476 - val_loss: 159.8399
#
# Epoch 00171: val_loss did not improve from 154.75139
# Epoch 172/400
#  - 8s - loss: 190.6884 - val_loss: 161.2537
#
# Epoch 00172: val_loss did not improve from 154.75139
# Epoch 173/400
#  - 8s - loss: 190.2650 - val_loss: 159.0326
#
# Epoch 00173: val_loss did not improve from 154.75139
# Epoch 174/400
#  - 8s - loss: 189.9504 - val_loss: 159.0027
#
# Epoch 00174: val_loss did not improve from 154.75139
# Epoch 175/400
#  - 8s - loss: 189.6313 - val_loss: 161.5920
#
# Epoch 00175: val_loss did not improve from 154.75139
# Epoch 176/400
#  - 8s - loss: 190.7225 - val_loss: 161.1924
#
# Epoch 00176: val_loss did not improve from 154.75139
# Epoch 177/400
#  - 8s - loss: 189.8919 - val_loss: 161.5116
#
# Epoch 00177: val_loss did not improve from 154.75139
# Epoch 178/400
#  - 8s - loss: 190.1727 - val_loss: 159.1840
#
# Epoch 00178: val_loss did not improve from 154.75139
# Epoch 179/400
#  - 8s - loss: 190.3365 - val_loss: 160.1281
#
# Epoch 00179: val_loss did not improve from 154.75139
# Epoch 180/400
#  - 8s - loss: 190.1841 - val_loss: 160.5643
#
# Epoch 00180: val_loss did not improve from 154.75139
# Epoch 181/400
#  - 8s - loss: 189.6484 - val_loss: 160.0405
#
# Epoch 00181: val_loss did not improve from 154.75139
# Epoch 182/400
#  - 8s - loss: 190.1866 - val_loss: 162.3066
#
# Epoch 00182: val_loss did not improve from 154.75139
# Epoch 183/400
#  - 8s - loss: 189.5307 - val_loss: 157.7244
#
# Epoch 00183: val_loss did not improve from 154.75139
# Epoch 184/400
#  - 8s - loss: 189.8698 - val_loss: 161.0154
#
# Epoch 00184: val_loss did not improve from 154.75139
# Epoch 185/400
#  - 8s - loss: 189.7600 - val_loss: 157.1587
#
# Epoch 00185: val_loss did not improve from 154.75139
# Epoch 186/400
#  - 8s - loss: 190.2822 - val_loss: 156.5980
#
# Epoch 00186: val_loss did not improve from 154.75139
# Epoch 187/400
#  - 8s - loss: 189.7818 - val_loss: 160.4819
#
# Epoch 00187: val_loss did not improve from 154.75139
# Epoch 188/400
#  - 8s - loss: 189.9011 - val_loss: 160.4306
#
# Epoch 00188: val_loss did not improve from 154.75139
# Epoch 189/400
#  - 8s - loss: 190.2647 - val_loss: 162.4083
#
# Epoch 00189: val_loss did not improve from 154.75139
# Epoch 190/400
#  - 8s - loss: 189.4793 - val_loss: 159.0888
#
# Epoch 00190: val_loss did not improve from 154.75139
# Epoch 191/400
#  - 8s - loss: 189.6763 - val_loss: 158.8771
#
# Epoch 00191: val_loss did not improve from 154.75139
# Epoch 192/400
#  - 8s - loss: 189.5749 - val_loss: 160.1528
#
# Epoch 00192: val_loss did not improve from 154.75139
# Epoch 193/400
#  - 8s - loss: 189.9204 - val_loss: 160.4893
#
# Epoch 00193: val_loss did not improve from 154.75139
# Epoch 194/400
#  - 8s - loss: 188.9152 - val_loss: 157.8658
#
# Epoch 00194: val_loss did not improve from 154.75139
# Epoch 195/400
#  - 8s - loss: 189.9418 - val_loss: 161.3769
#
# Epoch 00195: val_loss did not improve from 154.75139
# Epoch 196/400
#  - 8s - loss: 189.9363 - val_loss: 160.3460
#
# Epoch 00196: val_loss did not improve from 154.75139
# Epoch 197/400
#  - 8s - loss: 190.2932 - val_loss: 158.0695
#
# Epoch 00197: val_loss did not improve from 154.75139
# Epoch 198/400
#  - 8s - loss: 189.1539 - val_loss: 161.9479
#
# Epoch 00198: val_loss did not improve from 154.75139
# Epoch 199/400
#  - 8s - loss: 189.4020 - val_loss: 159.9175
#
# Epoch 00199: val_loss did not improve from 154.75139
# Epoch 200/400
#  - 8s - loss: 190.2166 - val_loss: 159.9672
#
# Epoch 00200: val_loss did not improve from 154.75139
# Epoch 201/400
#  - 8s - loss: 189.0570 - val_loss: 159.6107
#
# Epoch 00201: val_loss did not improve from 154.75139
# Epoch 202/400
#  - 8s - loss: 188.9130 - val_loss: 159.1969
#
# Epoch 00202: val_loss did not improve from 154.75139
# Epoch 203/400
#  - 8s - loss: 190.0693 - val_loss: 160.0093
#
# Epoch 00203: val_loss did not improve from 154.75139
# Epoch 204/400
#  - 8s - loss: 189.5143 - val_loss: 161.4579
#
# Epoch 00204: val_loss did not improve from 154.75139
# Epoch 205/400
#  - 8s - loss: 189.4773 - val_loss: 159.7310
#
# Epoch 00205: val_loss did not improve from 154.75139
# Epoch 206/400
#  - 8s - loss: 189.4975 - val_loss: 158.5169
#
# Epoch 00206: val_loss did not improve from 154.75139
# Epoch 207/400
#  - 8s - loss: 189.3054 - val_loss: 161.5064
#
# Epoch 00207: val_loss did not improve from 154.75139
# Epoch 208/400
#  - 8s - loss: 189.3740 - val_loss: 157.0725
#
# Epoch 00208: val_loss did not improve from 154.75139
# Epoch 209/400
#  - 8s - loss: 188.9053 - val_loss: 159.4300
# Epoch 00209: val_loss did not improve from 154.75139
# Epoch 210/400
#  - 8s - loss: 189.8082 - val_loss: 159.1878
#
# Epoch 00210: val_loss did not improve from 154.75139
# Epoch 211/400
#  - 8s - loss: 189.4155 - val_loss: 162.6682
#
# Epoch 00211: val_loss did not improve from 154.75139
# Epoch 212/400
#  - 8s - loss: 189.4775 - val_loss: 159.3103
#
# Epoch 00212: val_loss did not improve from 154.75139
# Epoch 213/400
#  - 8s - loss: 189.0731 - val_loss: 160.9563
#
# Epoch 00213: val_loss did not improve from 154.75139
# Epoch 214/400
#  - 8s - loss: 189.6914 - val_loss: 161.4117
#
# Epoch 00214: val_loss did not improve from 154.75139
# Epoch 215/400
#  - 8s - loss: 188.6561 - val_loss: 161.5024
#
# Epoch 00215: val_loss did not improve from 154.75139
# Epoch 216/400
#  - 8s - loss: 189.6598 - val_loss: 155.5833
#
# Epoch 00216: val_loss did not improve from 154.75139
# Epoch 217/400
#  - 8s - loss: 188.9019 - val_loss: 162.4335
#
# Epoch 00217: val_loss did not improve from 154.75139
# Epoch 218/400
#  - 8s - loss: 189.3213 - val_loss: 163.4160
#
# Epoch 00218: val_loss did not improve from 154.75139
# Epoch 219/400
#  - 8s - loss: 189.1027 - val_loss: 156.0092
#
# Epoch 00219: val_loss did not improve from 154.75139
# Epoch 220/400
#  - 8s - loss: 189.4890 - val_loss: 162.5728
#
# Epoch 00220: val_loss did not improve from 154.75139
# Epoch 221/400
#  - 8s - loss: 188.3750 - val_loss: 160.7188
#
# Epoch 00221: val_loss did not improve from 154.75139
# Epoch 222/400
#  - 8s - loss: 189.1708 - val_loss: 160.8139
#
# Epoch 00222: val_loss did not improve from 154.75139
# Epoch 223/400
#  - 8s - loss: 189.3636 - val_loss: 157.7860
#
# Epoch 00223: val_loss did not improve from 154.75139
# Epoch 224/400
#  - 8s - loss: 188.9556 - val_loss: 157.9036
#
# Epoch 00224: val_loss did not improve from 154.75139
# Epoch 225/400
#  - 8s - loss: 189.6195 - val_loss: 161.3229
#
# Epoch 00225: val_loss did not improve from 154.75139
# Epoch 226/400
#  - 8s - loss: 189.4511 - val_loss: 159.3672
#
# Epoch 00226: val_loss did not improve from 154.75139
# Epoch 227/400
#  - 8s - loss: 188.3864 - val_loss: 162.9999
#
# Epoch 00227: val_loss did not improve from 154.75139
# Epoch 228/400
#  - 8s - loss: 188.2132 - val_loss: 160.8177
#
# Epoch 00228: val_loss did not improve from 154.75139
# Epoch 229/400
#  - 8s - loss: 189.7104 - val_loss: 159.1578
#
# Epoch 00229: val_loss did not improve from 154.75139
# Epoch 230/400
#  - 8s - loss: 189.2784 - val_loss: 160.7043
#
# Epoch 00230: val_loss did not improve from 154.75139
# Epoch 231/400
#  - 8s - loss: 189.2714 - val_loss: 162.1578
#
# Epoch 00231: val_loss did not improve from 154.75139
# Epoch 232/400
#  - 8s - loss: 188.3552 - val_loss: 159.8833
#
# Epoch 00232: val_loss did not improve from 154.75139
# Epoch 233/400
#  - 8s - loss: 188.9141 - val_loss: 158.0637
#
# Epoch 00233: val_loss did not improve from 154.75139
# Epoch 234/400
#  - 8s - loss: 189.0086 - val_loss: 156.9814
#
# Epoch 00234: val_loss did not improve from 154.75139
# Epoch 235/400
#  - 8s - loss: 188.7327 - val_loss: 162.6340
#
# Epoch 00235: val_loss did not improve from 154.75139
# Epoch 236/400
#  - 8s - loss: 188.5721 - val_loss: 159.7624
#
# Epoch 00236: val_loss did not improve from 154.75139
# Epoch 237/400
#  - 8s - loss: 188.9424 - val_loss: 158.4174
#
# Epoch 00237: val_loss did not improve from 154.75139
# Epoch 238/400
#  - 8s - loss: 188.8496 - val_loss: 160.8923
#
# Epoch 00238: val_loss did not improve from 154.75139
# Epoch 239/400
#  - 8s - loss: 188.9980 - val_loss: 158.6045
#
# Epoch 00239: val_loss did not improve from 154.75139
# Epoch 240/400
#  - 8s - loss: 188.4709 - val_loss: 159.7371
#
# Epoch 00240: val_loss did not improve from 154.75139
# Epoch 241/400
#  - 8s - loss: 188.6905 - val_loss: 158.3005
#
# Epoch 00241: val_loss did not improve from 154.75139
# Epoch 242/400
#  - 8s - loss: 189.0242 - val_loss: 159.1099
#
# Epoch 00242: val_loss did not improve from 154.75139
# Epoch 243/400
#  - 8s - loss: 189.1698 - val_loss: 158.9844
#
# Epoch 00243: val_loss did not improve from 154.75139
# Epoch 244/400
#  - 8s - loss: 188.2118 - val_loss: 162.5351
#
# Epoch 00244: val_loss did not improve from 154.75139
# Epoch 245/400
#  - 8s - loss: 188.8651 - val_loss: 160.6734
#
# Epoch 00245: val_loss did not improve from 154.75139
# Epoch 246/400
#  - 8s - loss: 188.7042 - val_loss: 159.7208
#
# Epoch 00246: val_loss did not improve from 154.75139
# Epoch 247/400
#  - 8s - loss: 188.6174 - val_loss: 158.5369
#
# Epoch 00247: val_loss did not improve from 154.75139
# Epoch 248/400
#  - 8s - loss: 188.7025 - val_loss: 161.1088
#
# Epoch 00248: val_loss did not improve from 154.75139
# Epoch 249/400
#  - 8s - loss: 188.0880 - val_loss: 163.6304
#
# Epoch 00249: val_loss did not improve from 154.75139
# Epoch 250/400
#  - 8s - loss: 188.6618 - val_loss: 162.5018
#
# Epoch 00250: val_loss did not improve from 154.75139
# Epoch 251/400
#  - 8s - loss: 188.3807 - val_loss: 161.0732
#
# Epoch 00251: val_loss did not improve from 154.75139
# Epoch 252/400
#  - 8s - loss: 188.8076 - val_loss: 156.7757
#
# Epoch 00252: val_loss did not improve from 154.75139
# Epoch 253/400
#  - 8s - loss: 188.6870 - val_loss: 162.9347
#
# Epoch 00253: val_loss did not improve from 154.75139
# Epoch 254/400
#  - 8s - loss: 188.1838 - val_loss: 159.8069
#
# Epoch 00254: val_loss did not improve from 154.75139
# Epoch 255/400
#  - 8s - loss: 188.6069 - val_loss: 158.0031
#
# Epoch 00255: val_loss did not improve from 154.75139
# Epoch 256/400
#  - 8s - loss: 188.6595 - val_loss: 161.1165
#
# Epoch 00256: val_loss did not improve from 154.75139
# Epoch 257/400
#  - 8s - loss: 188.3423 - val_loss: 163.3904
#
# Epoch 00257: val_loss did not improve from 154.75139
# Epoch 258/400
#  - 8s - loss: 188.6135 - val_loss: 162.7283
#
# Epoch 00258: val_loss did not improve from 154.75139
# Epoch 259/400
#  - 8s - loss: 188.4732 - val_loss: 160.8446
#
# Epoch 00259: val_loss did not improve from 154.75139
# Epoch 260/400
#  - 8s - loss: 188.3690 - val_loss: 160.6709
#
# Epoch 00260: val_loss did not improve from 154.75139
# Epoch 261/400
#  - 8s - loss: 188.2028 - val_loss: 160.6812
#
# Epoch 00261: val_loss did not improve from 154.75139
# Epoch 262/400
#  - 8s - loss: 188.7146 - val_loss: 158.8524
#
# Epoch 00262: val_loss did not improve from 154.75139
# Epoch 263/400
#  - 8s - loss: 188.1785 - val_loss: 157.8901
#
# Epoch 00263: val_loss did not improve from 154.75139
# Epoch 264/400
#  - 8s - loss: 188.4319 - val_loss: 161.2531
#
# Epoch 00264: val_loss did not improve from 154.75139
# Epoch 265/400
#  - 8s - loss: 188.2066 - val_loss: 161.7363
#
# Epoch 00265: val_loss did not improve from 154.75139
# Epoch 266/400
#  - 8s - loss: 188.2151 - val_loss: 161.0362
#
# Epoch 00266: val_loss did not improve from 154.75139
# Epoch 267/400
#  - 8s - loss: 188.1602 - val_loss: 158.6132
#
# Epoch 00267: val_loss did not improve from 154.75139
# Epoch 268/400
#  - 8s - loss: 188.1617 - val_loss: 158.8393
#
# Epoch 00268: val_loss did not improve from 154.75139
# Epoch 269/400
#  - 8s - loss: 188.3988 - val_loss: 160.8970
#
# Epoch 00269: val_loss did not improve from 154.75139
# Epoch 270/400
#  - 9s - loss: 188.2254 - val_loss: 163.5643
#
# Epoch 00270: val_loss did not improve from 154.75139
# Epoch 271/400
#  - 9s - loss: 188.1951 - val_loss: 161.4795
#
# Epoch 00271: val_loss did not improve from 154.75139
# Epoch 272/400
#  - 9s - loss: 188.5134 - val_loss: 159.4921
#
# Epoch 00272: val_loss did not improve from 154.75139
# Epoch 273/400
#  - 9s - loss: 188.0143 - val_loss: 161.7914
#
# Epoch 00273: val_loss did not improve from 154.75139
# Epoch 274/400
#  - 9s - loss: 187.4627 - val_loss: 161.4681
#
# Epoch 00274: val_loss did not improve from 154.75139
# Epoch 275/400
#  - 9s - loss: 188.1037 - val_loss: 158.0634
#
# Epoch 00275: val_loss did not improve from 154.75139
# Epoch 276/400
#  - 9s - loss: 189.4598 - val_loss: 160.7516
#
# Epoch 00276: val_loss did not improve from 154.75139
# Epoch 277/400
#  - 9s - loss: 187.7268 - val_loss: 158.4187
#
# Epoch 00277: val_loss did not improve from 154.75139
# Epoch 278/400
#  - 9s - loss: 188.2068 - val_loss: 160.0794
#
# Epoch 00278: val_loss did not improve from 154.75139
# Epoch 279/400
#  - 9s - loss: 187.9644 - val_loss: 159.6497
#
# Epoch 00279: val_loss did not improve from 154.75139
# Epoch 280/400
#  - 9s - loss: 188.3794 - val_loss: 161.6498
#
# Epoch 00280: val_loss did not improve from 154.75139
# Epoch 281/400
#  - 9s - loss: 187.9452 - val_loss: 160.0698
#
# Epoch 00281: val_loss did not improve from 154.75139
# Epoch 282/400
#  - 9s - loss: 187.9229 - val_loss: 162.1262
#
# Epoch 00282: val_loss did not improve from 154.75139
# Epoch 283/400
#  - 9s - loss: 187.8082 - val_loss: 160.4793
#
# Epoch 00283: val_loss did not improve from 154.75139
# Epoch 284/400
#  - 9s - loss: 188.2001 - val_loss: 157.5987
#
# Epoch 00284: val_loss did not improve from 154.75139
# Epoch 285/400
#  - 9s - loss: 188.0386 - val_loss: 163.0069
#
# Epoch 00285: val_loss did not improve from 154.75139
# Epoch 286/400
#  - 9s - loss: 187.8965 - val_loss: 159.1442
#
# Epoch 00286: val_loss did not improve from 154.75139
# Epoch 287/400
#  - 9s - loss: 187.5631 - val_loss: 159.8370
#
# Epoch 00287: val_loss did not improve from 154.75139
# Epoch 288/400
#  - 9s - loss: 188.5951 - val_loss: 161.3595
#
# Epoch 00288: val_loss did not improve from 154.75139
# Epoch 289/400
#  - 9s - loss: 187.9829 - val_loss: 163.2954
#
# Epoch 00289: val_loss did not improve from 154.75139
# Epoch 290/400
#  - 9s - loss: 187.7689 - val_loss: 161.3183
#
# Epoch 00290: val_loss did not improve from 154.75139
# Epoch 291/400
#  - 9s - loss: 188.0054 - val_loss: 160.6739
#
# Epoch 00291: val_loss did not improve from 154.75139
# Epoch 292/400
#  - 9s - loss: 187.3116 - val_loss: 158.6711
#
# Epoch 00292: val_loss did not improve from 154.75139
# Epoch 293/400
#  - 9s - loss: 188.3675 - val_loss: 160.0486
#
# Epoch 00293: val_loss did not improve from 154.75139
# Epoch 294/400
#  - 9s - loss: 187.7381 - val_loss: 163.4486
#
# Epoch 00294: val_loss did not improve from 154.75139
# Epoch 295/400
#  - 9s - loss: 188.2759 - val_loss: 159.8397
#
# Epoch 00295: val_loss did not improve from 154.75139
# Epoch 296/400
#  - 8s - loss: 187.7737 - val_loss: 160.6041
#
# Epoch 00296: val_loss did not improve from 154.75139
# Epoch 297/400
#  - 8s - loss: 187.8612 - val_loss: 161.8626
#
# Epoch 00297: val_loss did not improve from 154.75139
# Epoch 298/400
#  - 8s - loss: 187.2332 - val_loss: 159.3846
#
# Epoch 00298: val_loss did not improve from 154.75139
# Epoch 299/400
#  - 8s - loss: 188.5337 - val_loss: 159.5036
#
# Epoch 00299: val_loss did not improve from 154.75139
# Epoch 300/400
#  - 8s - loss: 187.2689 - val_loss: 160.3154
#
# Epoch 00300: val_loss did not improve from 154.75139
# Epoch 301/400
#  - 8s - loss: 187.2798 - val_loss: 162.0379
#
# Epoch 00301: val_loss did not improve from 154.75139
# Epoch 302/400
#  - 8s - loss: 188.2575 - val_loss: 158.4020
#
# Epoch 00302: val_loss did not improve from 154.75139
# Epoch 303/400
#  - 8s - loss: 187.2649 - val_loss: 159.7558
#
# Epoch 00303: val_loss did not improve from 154.75139
# Epoch 304/400
#  - 8s - loss: 187.9741 - val_loss: 162.9005
#
# Epoch 00304: val_loss did not improve from 154.75139
# Epoch 305/400
#  - 8s - loss: 188.3493 - val_loss: 159.8172
#
# Epoch 00305: val_loss did not improve from 154.75139
# Epoch 306/400
#  - 8s - loss: 187.6990 - val_loss: 162.2499
#
# Epoch 00306: val_loss did not improve from 154.75139
# Epoch 307/400
#  - 8s - loss: 187.4782 - val_loss: 162.6074
#
# Epoch 00307: val_loss did not improve from 154.75139
# Epoch 308/400
#  - 8s - loss: 187.8175 - val_loss: 160.6710
#
# Epoch 00308: val_loss did not improve from 154.75139
# Epoch 309/400
#  - 8s - loss: 187.0937 - val_loss: 159.3122
#
# Epoch 00309: val_loss did not improve from 154.75139
# Epoch 310/400
#  - 8s - loss: 188.3905 - val_loss: 159.5970
#
# Epoch 00310: val_loss did not improve from 154.75139
# Epoch 311/400
#  - 7s - loss: 187.4654 - val_loss: 162.1842
#
# Epoch 00311: val_loss did not improve from 154.75139
# Epoch 312/400
#  - 8s - loss: 187.1037 - val_loss: 159.9384
#
# Epoch 00312: val_loss did not improve from 154.75139
# Epoch 313/400
#  - 8s - loss: 187.9264 - val_loss: 161.6100
#
# Epoch 00313: val_loss did not improve from 154.75139
# Epoch 314/400
#  - 9s - loss: 187.6212 - val_loss: 160.1113
#
# Epoch 00314: val_loss did not improve from 154.75139
# Epoch 315/400
#  - 9s - loss: 187.0103 - val_loss: 161.1852
#
# Epoch 00315: val_loss did not improve from 154.75139
# Epoch 316/400
#  - 8s - loss: 187.7040 - val_loss: 160.4603
#
# Epoch 00316: val_loss did not improve from 154.75139
# Epoch 317/400
#  - 8s - loss: 187.7680 - val_loss: 159.3689
#
# Epoch 00317: val_loss did not improve from 154.75139
# Epoch 318/400
#  - 8s - loss: 187.7779 - val_loss: 159.6669
#
# Epoch 00318: val_loss did not improve from 154.75139
# Epoch 319/400
#  - 8s - loss: 187.2069 - val_loss: 161.6447
#
# Epoch 00319: val_loss did not improve from 154.75139
# Epoch 320/400
#  - 8s - loss: 187.3039 - val_loss: 162.4362
#
# Epoch 00320: val_loss did not improve from 154.75139
# Epoch 321/400
#  - 8s - loss: 187.7675 - val_loss: 161.0674
#
# Epoch 00321: val_loss did not improve from 154.75139
# Epoch 322/400
#  - 8s - loss: 187.0620 - val_loss: 160.5167
#
# Epoch 00322: val_loss did not improve from 154.75139
# Epoch 323/400
#  - 8s - loss: 187.4971 - val_loss: 163.1029
#
# Epoch 00323: val_loss did not improve from 154.75139
# Epoch 324/400
#  - 8s - loss: 187.9689 - val_loss: 160.8795
#
# Epoch 00324: val_loss did not improve from 154.75139
# Epoch 325/400
#  - 8s - loss: 187.2784 - val_loss: 158.2327
#
# Epoch 00325: val_loss did not improve from 154.75139
# Epoch 326/400
#  - 8s - loss: 187.1258 - val_loss: 162.0619
#
# Epoch 00326: val_loss did not improve from 154.75139
# Epoch 327/400
#  - 9s - loss: 187.7425 - val_loss: 163.0221
#
# Epoch 00327: val_loss did not improve from 154.75139
# Epoch 328/400
#  - 8s - loss: 186.8876 - val_loss: 161.2106
#
# Epoch 00328: val_loss did not improve from 154.75139
# Epoch 329/400
#  - 8s - loss: 187.6379 - val_loss: 162.8951
#
# Epoch 00329: val_loss did not improve from 154.75139
# Epoch 330/400
#  - 8s - loss: 187.4366 - val_loss: 161.0523
#
# Epoch 00330: val_loss did not improve from 154.75139
# Epoch 331/400
#  - 8s - loss: 187.1486 - val_loss: 160.5930
#
# Epoch 00331: val_loss did not improve from 154.75139
# Epoch 332/400
#  - 8s - loss: 187.7087 - val_loss: 160.7074
#
# Epoch 00332: val_loss did not improve from 154.75139
# Epoch 333/400
#  - 8s - loss: 186.9088 - val_loss: 158.7881
#
# Epoch 00333: val_loss did not improve from 154.75139
# Epoch 334/400
#  - 8s - loss: 187.6460 - val_loss: 161.6192
#
# Epoch 00334: val_loss did not improve from 154.75139
# Epoch 335/400
#  - 8s - loss: 187.0955 - val_loss: 161.2018
#
# Epoch 00335: val_loss did not improve from 154.75139
# Epoch 336/400
#  - 8s - loss: 187.1164 - val_loss: 157.3622
#
# Epoch 00336: val_loss did not improve from 154.75139
# Epoch 337/400
#  - 8s - loss: 187.2617 - val_loss: 163.0415
#
# Epoch 00337: val_loss did not improve from 154.75139
# Epoch 338/400
#  - 8s - loss: 187.0362 - val_loss: 158.0719
#
# Epoch 00338: val_loss did not improve from 154.75139
# Epoch 339/400
#  - 8s - loss: 187.4003 - val_loss: 164.7134
#
# Epoch 00339: val_loss did not improve from 154.75139
# Epoch 340/400
#  - 8s - loss: 186.8175 - val_loss: 159.3269
#
# Epoch 00340: val_loss did not improve from 154.75139
# Epoch 341/400
#  - 8s - loss: 187.8226 - val_loss: 158.2063
#
# Epoch 00341: val_loss did not improve from 154.75139
# Epoch 342/400
#  - 8s - loss: 187.1308 - val_loss: 159.8814
#
# Epoch 00342: val_loss did not improve from 154.75139
# Epoch 343/400
#  - 8s - loss: 186.9833 - val_loss: 163.1880
#
# Epoch 00343: val_loss did not improve from 154.75139
# Epoch 344/400
#  - 8s - loss: 187.7154 - val_loss: 159.3985
#
# Epoch 00344: val_loss did not improve from 154.75139
# Epoch 345/400
#  - 8s - loss: 186.4121 - val_loss: 159.5104
#
# Epoch 00345: val_loss did not improve from 154.75139
# Epoch 346/400
#  - 8s - loss: 187.4933 - val_loss: 158.8850
#
# Epoch 00346: val_loss did not improve from 154.75139
# Epoch 347/400
#  - 8s - loss: 186.5519 - val_loss: 162.3396
#
# Epoch 00347: val_loss did not improve from 154.75139
# Epoch 348/400
#  - 8s - loss: 187.7360 - val_loss: 162.6567
#
# Epoch 00348: val_loss did not improve from 154.75139
# Epoch 349/400
#  - 8s - loss: 186.1963 - val_loss: 163.9503
#
# Epoch 00349: val_loss did not improve from 154.75139
# Epoch 350/400
#  - 8s - loss: 187.6255 - val_loss: 161.1890
#
# Epoch 00350: val_loss did not improve from 154.75139
# Epoch 351/400
#  - 8s - loss: 187.2947 - val_loss: 160.7640
#
# Epoch 00351: val_loss did not improve from 154.75139
# Epoch 352/400
#  - 8s - loss: 187.7055 - val_loss: 162.4779
#
# Epoch 00352: val_loss did not improve from 154.75139
# Epoch 353/400
#  - 8s - loss: 186.6081 - val_loss: 160.8891
#
# Epoch 00353: val_loss did not improve from 154.75139
# Epoch 354/400
#  - 8s - loss: 187.1627 - val_loss: 160.9515
#
# Epoch 00354: val_loss did not improve from 154.75139
# Epoch 355/400
#  - 8s - loss: 187.2467 - val_loss: 159.6140
#
# Epoch 00355: val_loss did not improve from 154.75139
# Epoch 356/400
#  - 8s - loss: 186.8968 - val_loss: 161.1380
# Epoch 00356: val_loss did not improve from 154.75139
# Epoch 357/400
#  - 8s - loss: 186.8887 - val_loss: 161.9359
#
# Epoch 00357: val_loss did not improve from 154.75139
# Epoch 358/400
#  - 8s - loss: 186.8523 - val_loss: 158.8164
#
# Epoch 00358: val_loss did not improve from 154.75139
# Epoch 359/400
#  - 8s - loss: 186.9637 - val_loss: 160.9624
#
# Epoch 00359: val_loss did not improve from 154.75139
# Epoch 360/400
#  - 8s - loss: 186.8654 - val_loss: 164.3261
#
# Epoch 00360: val_loss did not improve from 154.75139
# Epoch 361/400
#  - 8s - loss: 186.7517 - val_loss: 160.6198
#
# Epoch 00361: val_loss did not improve from 154.75139
# Epoch 362/400
#  - 8s - loss: 187.1286 - val_loss: 160.1948
#
# Epoch 00362: val_loss did not improve from 154.75139
# Epoch 363/400
#  - 8s - loss: 186.7327 - val_loss: 160.4705
#
# Epoch 00363: val_loss did not improve from 154.75139
# Epoch 364/400
#  - 8s - loss: 186.9298 - val_loss: 161.4710
#
# Epoch 00364: val_loss did not improve from 154.75139
# Epoch 365/400
#  - 8s - loss: 186.8330 - val_loss: 160.8777
#
# Epoch 00365: val_loss did not improve from 154.75139
# Epoch 366/400
#  - 8s - loss: 186.9378 - val_loss: 162.2384
#
# Epoch 00366: val_loss did not improve from 154.75139
# Epoch 367/400
#  - 8s - loss: 187.0028 - val_loss: 163.1231
#
# Epoch 00367: val_loss did not improve from 154.75139
# Epoch 368/400
#  - 8s - loss: 186.9894 - val_loss: 161.9865
#
# Epoch 00368: val_loss did not improve from 154.75139
# Epoch 369/400
#  - 8s - loss: 186.9651 - val_loss: 159.8132
#
# Epoch 00369: val_loss did not improve from 154.75139
# Epoch 370/400
#  - 8s - loss: 186.6107 - val_loss: 161.6154
#
# Epoch 00370: val_loss did not improve from 154.75139
# Epoch 371/400
#  - 8s - loss: 186.3217 - val_loss: 163.5325
#
# Epoch 00371: val_loss did not improve from 154.75139
# Epoch 372/400
#  - 8s - loss: 187.0747 - val_loss: 160.5449
#
# Epoch 00372: val_loss did not improve from 154.75139
# Epoch 373/400
#  - 8s - loss: 186.4335 - val_loss: 159.2371
#
# Epoch 00373: val_loss did not improve from 154.75139
# Epoch 374/400
#  - 8s - loss: 186.7423 - val_loss: 157.3543
#
# Epoch 00374: val_loss did not improve from 154.75139
# Epoch 375/400
#  - 8s - loss: 187.0599 - val_loss: 161.1075
#
# Epoch 00375: val_loss did not improve from 154.75139
# Epoch 376/400
#  - 8s - loss: 186.7282 - val_loss: 162.2729
#
# Epoch 00376: val_loss did not improve from 154.75139
# Epoch 377/400
#  - 8s - loss: 186.8124 - val_loss: 159.9342
#
# Epoch 00377: val_loss did not improve from 154.75139
# Epoch 378/400
#  - 8s - loss: 186.6160 - val_loss: 160.3187
#
# Epoch 00378: val_loss did not improve from 154.75139
# Epoch 379/400
#  - 8s - loss: 186.8196 - val_loss: 163.5733
#
# Epoch 00379: val_loss did not improve from 154.75139
# Epoch 380/400
#  - 8s - loss: 186.4851 - val_loss: 160.1662
#
# Epoch 00380: val_loss did not improve from 154.75139
# Epoch 381/400
#  - 8s - loss: 186.6591 - val_loss: 162.9002
#
# Epoch 00381: val_loss did not improve from 154.75139
# Epoch 382/400
#  - 8s - loss: 186.6247 - val_loss: 163.7585
#
# Epoch 00382: val_loss did not improve from 154.75139
# Epoch 383/400
#  - 8s - loss: 186.5315 - val_loss: 159.6003
#
# Epoch 00383: val_loss did not improve from 154.75139
# Epoch 384/400
#  - 8s - loss: 186.4847 - val_loss: 159.4607
#
# Epoch 00384: val_loss did not improve from 154.75139
# Epoch 385/400
#  - 8s - loss: 186.6383 - val_loss: 163.8977
#
# Epoch 00385: val_loss did not improve from 154.75139
# Epoch 386/400
#  - 8s - loss: 186.6920 - val_loss: 160.3569
#
# Epoch 00386: val_loss did not improve from 154.75139
# Epoch 387/400
#  - 8s - loss: 186.8401 - val_loss: 163.3652
#
# Epoch 00387: val_loss did not improve from 154.75139
# Epoch 388/400
#  - 8s - loss: 186.7197 - val_loss: 159.6948
#
# Epoch 00388: val_loss did not improve from 154.75139
# Epoch 389/400
#  - 8s - loss: 186.4612 - val_loss: 159.3537
#
# Epoch 00389: val_loss did not improve from 154.75139
# Epoch 390/400
#  - 8s - loss: 186.9722 - val_loss: 162.4642
#
# Epoch 00390: val_loss did not improve from 154.75139
# Epoch 391/400
#  - 8s - loss: 186.5235 - val_loss: 159.6931
#
# Epoch 00391: val_loss did not improve from 154.75139
# Epoch 392/400
#  - 8s - loss: 186.5582 - val_loss: 162.4631
#
# Epoch 00392: val_loss did not improve from 154.75139
# Epoch 393/400
#  - 8s - loss: 186.7380 - val_loss: 158.9801
#
# Epoch 00393: val_loss did not improve from 154.75139
# Epoch 394/400
#  - 8s - loss: 186.1165 - val_loss: 160.5078
#
# Epoch 00394: val_loss did not improve from 154.75139
# Epoch 395/400
#  - 8s - loss: 186.0231 - val_loss: 161.4036
#
# Epoch 00395: val_loss did not improve from 154.75139
# Epoch 396/400
#  - 8s - loss: 186.8580 - val_loss: 162.8745
#
# Epoch 00396: val_loss did not improve from 154.75139
# Epoch 397/400
#  - 8s - loss: 186.7146 - val_loss: 158.7626
#
# Epoch 00397: val_loss did not improve from 154.75139
# Epoch 398/400
#  - 8s - loss: 186.4758 - val_loss: 162.2053
#
# Epoch 00398: val_loss did not improve from 154.75139
# Epoch 399/400
#  - 8s - loss: 186.3328 - val_loss: 164.0018
#
# Epoch 00399: val_loss did not improve from 154.75139
# Epoch 400/400
#  - 8s - loss: 186.6363 - val_loss: 163.8103
#
# Epoch 00400: val_loss did not improve from 154.75139

# %% [markdown]
# ### Decoder model

# %%
# Decoding Model
# Same as training model except for dimension and mixtures.

decoder = keras.Sequential()
decoder.add(keras.layers.LSTM(HIDDEN_UNITS, batch_input_shape=(1,1,OUTPUT_DIMENSION), return_sequences=True, stateful=True))
decoder.add(keras.layers.LSTM(HIDDEN_UNITS, stateful=True))
decoder.add(mdn.MDN(OUTPUT_DIMENSION, NUMBER_MIXTURES))
decoder.compile(loss=mdn.get_mixture_loss_func(OUTPUT_DIMENSION,NUMBER_MIXTURES), optimizer=keras.optimizers.Adam())
decoder.summary()


decoder.load_weights("weights/MDN_pre-weights-improvement-86-155.28.hdf5")
print("Loaded MDN weights from disk")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (1, 1, 512)               1181696
# _________________________________________________________________
# lstm_2 (LSTM)                (1, 512)                  2099200
# _________________________________________________________________
# mdn_1 (MDN)                  (1, 1290)                 661770
# =================================================================
# Total params: 3,942,666
# Trainable params: 3,942,666
# Non-trainable params: 0
# _________________________________________________________________
# Loaded MDN weights from disk

# %% [markdown]
# ## Get MusicVAE

# %%
# define model
train, infenc, infdec = define_models(n_encoder_units=n_encoder_units,
                                        n_decoder_units=n_decoder_units,
                                        latent_dim=latent_dim, 
                                      timesteps=timesteps,
                                      n_features=n_features,
                                      learning_rate=learning_rate,
                                        dropout=dropout,
                                      beta=beta,
                                        epsilon_std=1.)

train.load_weights(vae_weights_path)
print("Loaded VAE weights from disk")

all_weights = train.get_weights()
decoder_position = len(infenc.get_weights())
decoder_weights = all_weights[decoder_position::]
encoder_weights = all_weights[:decoder_position]

infenc.set_weights(encoder_weights)
infdec.set_weights(decoder_weights)
# Out:
# Loaded VAE weights from disk

# %% [markdown]
# ## Predict

# %%
test_ID_list_dict = []
ID_list = np.load("ID_lists/test_ID_list.npy")

test_list = ID_list.item().get("test_labels")

input_songs = []
output_songs = []

ID = test_list[14]
encoder_input = np.load('encoder_inputs/' + ID + '.npy').reshape(1, SEQ_LEN, n_features)    

z = predict_z(infenc=infenc,source=encoder_input,latent_dim=OUTPUT_DIMENSION)

mdn_song = []

for i in range(25):

    params = decoder.predict(z.reshape(1,1,64))
    z = mdn.sample_from_output(params[0], OUTPUT_DIMENSION, NUMBER_MIXTURES, temp=1.5)

    song = mdn_predict_sequence(infdec=infdec,
                                 z=z,
                                 latent_dim=OUTPUT_DIMENSION,
                                 seq_len=SEQ_LEN,
                                 temperature=1,
                                 n_decoder_units=n_decoder_units)
    
    mdn_song.append(one_hot_decode(song.reshape(SEQ_LEN, 131)))

# %%
mdn_song = np.ravel(mdn_song)

# %%
mdn_song = switch_range(mdn_song)

# %%
melody_stream = noteArrayToStream(switch_range(list(np.ravel(mdn_song))))

melody_stream.show()
# Out:
# /home/viktoro/keras/venv/lib/python3.5/site-packages/music21/ipython21/objects.py:16: ResourceWarning: unclosed file <_io.BufferedReader name='/tmp/music21/tmperagkacn-1.png'>
#   data = open(fp, 'rb').read()

# %%
mdn_song
# Out:
# array([129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129,  70, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129,  95, 129, 128, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 128, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129,  59, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129,  65, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 128, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,  96, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129,  86,  68, 129, 129, 129, 129, 129, 129, 129,
#        129, 128, 129, 129, 129, 129, 129, 129,  82, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129,  92, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#         34, 129, 129, 129, 129, 129,  52, 129, 128, 129, 129, 129, 128,
#        129, 128, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129,  49, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129,  51, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129,  85, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129,  83, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 128, 129, 129, 129,  51, 129, 129,
#        129, 129, 129, 129, 129, 129, 129,  38, 129, 129, 129, 129, 129,
#        129, 129, 129, 129, 129, 129, 129, 129, 129, 129])
